# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a **student**, a **data scientist**, **AI researcher** or an **Artist**, Colab can make your work easier. Watch [The Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <h1>Now It's Your Turn!</h1>
#
# Write a python code that outputs 'Hello World' and run it.

# %%
#Write your Code here and click the 'Play Button' on the left to run the code.

# %%
#@markdown **Run this cell if you don't know what to do.** { display-mode: "form" }
print('Type: print("<Your Text>") in the code cell above to output <Your Text>')

# %% [markdown]
# <i>This tutorial was created by:</i> <br><br><b> Bello / aiXdesign</b> <br>
# <a href="https://aixdesign.space">aiXdesign</a>
# <a href="http://sofianbello.com">Web</a>
# <a href="mailto:safian.bello@haw-hamburg.de">Mail</a><br>
# <a href="https://github.com/sofianbello">GitHub</a>
# <a href="https://www.linkedin.com/in/sofian-bello-71148a218/">LinkedIn</a> <br><br>
# Feel free to get in touch!<br>
