# %% [markdown]
# # Mounting Google Drive
#
# In Colab there are two ways to mount your Google Drive.

# %% [markdown]
# **Method A:** Using the Interface
#
# This method is most useful when you work on a project that you create yourself from scratch.
#
# ---
#
# 1. Click on the file symbol on the left side.
#
#
# ![Colab_Files_01.png](data:image/png;base64,...)

# %% [markdown]
# 2. Click on the mount drive symbol
#
# ![Colab_Files_02.png](data:image/png;base64,...)

# %% [markdown]
# 3. Confirm
# ![Colab_Files_03.png](data:image/png;base64,...)
#
# Now your drive is mounted and listed as 'drive' in the file browser. To unmount press the unmount drive symbol.

# %% [markdown]
# **Method B:** Using Code
#
# This method is most useful when you cloned someone elses project and continue your work from there.
#
# 1. Add the following to a code block and run it:
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# %% [markdown]
# 2. Click the Link and sign in to authorize
#
# ![Colab_Files_02B.png](data:image/png;base64,...)

# %% [markdown]
# 3. Copy the code to your clipboard
#
# ![Colab_Files_04B.png](data:image/png;base64,...)

# %% [markdown]
# 4. Paste the code into the input field and confirm with **enter**.
#
# ![Colab_Files_05B.png](data:image/png;base64,...)

# %% [markdown]
# # It's your turn again!
# Try to mount your google drive using the methods mentioned above.

# %%
# Write your code here and run it by pressing the 'Play Button'
echo
# Out:
#   File "<ipython-input-2-99ed10fdd9ff>", line 2
#     echo Helloworld
#                   ^
# SyntaxError: invalid syntax
