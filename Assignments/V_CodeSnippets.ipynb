# %% [markdown]
# ## Code Snippets
# Remembering every single function can be tough even for coding experts that's why Colab has implemented a collection of **Code Snippets** to help out.
#
#
# ![CodeSnippets_01.png](data:image/png;base64,...)
#
# Code Snippets are very intuitive to work with and can speed up your work tremendously. Simply click on the symbol and search for something you want to do.
#
# ![CodeSnippets_02.png](data:image/png;base64,...)

# %% [markdown]
# ## Your Turn!
# Try to use Code Snippets to Upload an Image to your Google Drive.

# %%
#Start here!

# %% [markdown]
# <i>This tutorial was created by:</i> <br><br><b> Bello / aiXdesign</b> <br>
# <a href="https://aixdesign.space">aiXdesign</a>
# <a href="http://sofianbello.com">Web</a>
# <a href="mailto:safian.bello@haw-hamburg.de">Mail</a><br>
# <a href="https://github.com/sofianbello">GitHub</a>
# <a href="https://www.linkedin.com/in/sofian-bello-71148a218/">LinkedIn</a> <br><br>
# Feel free to get in touch!<br>
