# %% [markdown]
# #Basic Operations
#
# Now that you know how to mount your drive, let's take it a step further and see how to do basic operations in colab.

# %% [markdown]
# To **print the current working directory** run:
# ```
# pwd
# ```
# To **change the directory** run (replace *Destination* with a valid path e.G. /content/drive/MyDrive/AiXDesignKitchen/Workshop) :
#
# ```
# cd Destination
# ```
# To **create a new folder** run (replace *foldername* with a name of your choice:
#
# ```
# mkdir foldername
# ```
# To **create a file** you can run the following function:
# ```
# open("Filename.xyz", "x")
# ```
#
# To **delete a file** you can run this command:
# ```
# rm filepath/filename
# ```
# To **Upload a file** from your Local Machine to your drive run:
# ```
# from google.colab import files
#
# filename = list(files.upload().keys())[0]
# ```
#
# To comment use **#**
# ```
#  #This is a comment
# ```

# %% [markdown]
# # Your turn!
# 1. Create a folder named **Workshop** in your drive
# 2. Create a textfile named **HelloWorld** in **Workshop**
# 3. Upload an image to your drive.
# 4. Delete the **HelloWorld** file.

# %%
# Write your code here and run it by pressing the 'Play Button'

# %% [markdown]
# <i>This tutorial was created by:</i> <br><br><b> Bello / aiXdesign</b> <br>
# <a href="https://aixdesign.space">aiXdesign</a>
# <a href="http://sofianbello.com">Web</a>
# <a href="mailto:safian.bello@haw-hamburg.de">Mail</a><br>
# <a href="https://github.com/sofianbello">GitHub</a>
# <a href="https://www.linkedin.com/in/sofian-bello-71148a218/">LinkedIn</a> <br><br>
# Feel free to get in touch!<br>
